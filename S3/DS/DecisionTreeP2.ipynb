# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
import matplotlib.pyplot as plt
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from mlxtend.plotting  import plot_confusion_matrix

# %%
x,y=load_iris(return_X_y=True)
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
dtree =DecisionTreeRegressor(criterion="squared_error")

# %%
clf = dtree.fit(x_train,y_train)
y_pred=clf.predict(x_test)
print("Number of mislabeled points out of a total %d points :%d" % (x_test.shape[0],(y_test!=y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 45 points :1

# %%
y_pred
# Out:
# array([2., 1., 0., 2., 0., 2., 0., 1., 1., 1., 2., 1., 1., 1., 1., 0., 1.,
#        1., 0., 0., 2., 1., 0., 0., 2., 0., 0., 1., 1., 0., 2., 1., 0., 2.,
#        2., 1., 0., 2., 1., 1., 2., 0., 2., 0., 0.])

# %%
y_test
# Out:
# array([2, 1, 0, 2, 0, 2, 0, 1, 1, 1, 2, 1, 1, 1, 1, 0, 1, 1, 0, 0, 2, 1,
#        0, 0, 2, 0, 0, 1, 1, 0, 2, 1, 0, 2, 2, 1, 0, 1, 1, 1, 2, 0, 2, 0,
#        0])

# %%
print("Accuracy of the dtree Classifier is:",metrics.accuracy_score(y_pred,y_test)*100)
# Out:
# Accuracy of the dtree Classifier is: 97.77777777777777

# %%
cm=confusion_matrix(y_test,y_pred)
cm_display = metrics.ConfusionMatrixDisplay(confusion_matrix = cm, display_labels =["Setosa","Vercicolor","Virginica"])
cm_display.plot()
plt.show()

# %%
res=clf.predict([[5.1,3.5,1.4,0.2]])
if res==0:
    print("Setosa")
if res==1:
    print("Vercicolor")
if res==2:
    print("Virginica")
# Out:
# Setosa

# %%
res=clf.predict([[5.8,2.6,4,1.2]])
if res==0:
    print("Setosa")
if res==1:
    print("Vercicolor")
if res==2:
    print("Virginica")
# Out:
# Vercicolor

# %%
res=clf.predict([[6.8,3,5.5,2.1]])
if res==0:
    print("Setosa")
if res==1:
    print("Vercicolor")
if res==2:
    print("Virginica")
# Out:
# Virginica

# %%
from sklearn import tree
tree.plot_tree(clf,feature_names=load_iris().feature_names,class_names=["Setosa","Vercicolor","Virginica"],filled=True)
# Out:
# [Text(0.4, 0.9, 'petal length (cm) <= 2.35\nsquared_error = 0.693\nsamples = 105\nvalue = 1.048'),
#  Text(0.3, 0.7, 'squared_error = 0.0\nsamples = 34\nvalue = 0.0'),
#  Text(0.35, 0.8, 'True  '),
#  Text(0.5, 0.7, 'petal length (cm) <= 4.95\nsquared_error = 0.248\nsamples = 71\nvalue = 1.549'),
#  Text(0.45, 0.8, '  False'),
#  Text(0.2, 0.5, 'petal width (cm) <= 1.65\nsquared_error = 0.08\nsamples = 34\nvalue = 1.088'),
#  Text(0.1, 0.3, 'squared_error = 0.0\nsamples = 30\nvalue = 1.0'),
#  Text(0.3, 0.3, 'sepal width (cm) <= 3.1\nsquared_error = 0.188\nsamples = 4\nvalue = 1.75'),
#  Text(0.2, 0.1, 'squared_error = 0.0\nsamples = 3\nvalue = 2.0'),
#  Text(0.4, 0.1, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.8, 0.5, 'petal length (cm) <= 5.05\nsquared_error = 0.026\nsamples = 37\nvalue = 1.973'),
#  Text(0.7, 0.3, 'sepal length (cm) <= 6.5\nsquared_error = 0.188\nsamples = 4\nvalue = 1.75'),
#  Text(0.6, 0.1, 'squared_error = 0.0\nsamples = 3\nvalue = 2.0'),
#  Text(0.8, 0.1, 'squared_error = 0.0\nsamples = 1\nvalue = 1.0'),
#  Text(0.9, 0.3, 'squared_error = 0.0\nsamples = 33\nvalue = 2.0')]
