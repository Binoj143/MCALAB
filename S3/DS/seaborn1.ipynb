# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv('C:\\Users\\user\\Downloads\\iris.csv')
df
# Out:
#      sepal.length  sepal.width  petal.length  petal.width    variety
# 0             5.1          3.5           1.4          0.2     Setosa
# 1             4.9          3.0           1.4          0.2     Setosa
# 2             4.7          3.2           1.3          0.2     Setosa
# 3             4.6          3.1           1.5          0.2     Setosa
# 4             5.0          3.6           1.4          0.2     Setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  Virginica
# 146           6.3          2.5           5.0          1.9  Virginica
# 147           6.5          3.0           5.2          2.0  Virginica
# 148           6.2          3.4           5.4          2.3  Virginica
# 149           5.9          3.0           5.1          1.8  Virginica
#
# [150 rows x 5 columns]

# %%
sns.relplot(x='sepal.length',y='petal.length',data=df)

# %%
sns.relplot(x='sepal.length',y='petal.length',data=df,hue='variety')

# %%
sns.relplot(x='sepal.length',y='petal.length',data=df,hue='variety',style='sepal.length')

# %%
df['sepal.length'].value_counts()
# Out:
# sepal.length
# 5.0    10
# 6.3     9
# 5.1     9
# 6.7     8
# 5.7     8
# 6.4     7
# 5.5     7
# 5.8     7
# 4.9     6
# 6.0     6
# 5.4     6
# 5.6     6
# 6.1     6
# 6.5     5
# 4.8     5
# 7.7     4
# 6.9     4
# 4.6     4
# 5.2     4
# 6.2     4
# 4.4     3
# 7.2     3
# 5.9     3
# 6.8     3
# 4.7     2
# 6.6     2
# 4.3     1
# 7.0     1
# 5.3     1
# 4.5     1
# 7.1     1
# 7.3     1
# 7.6     1
# 7.4     1
# 7.9     1
# Name: count, dtype: int64

# %%
sns.relplot(x='sepal.length',y='petal.length',data=df,kind='line')

# %%
sns.relplot(x='sepal.length',y='petal.length',data=df,kind='line',height=5,aspect=4)

# %%
sns.relplot(x='sepal.length',y='petal.length',data=df,kind='line',height=5,aspect=4)
sns.set(font_scale=2)

# %%
sns.relplot(x='sepal.length',y='petal.length',data=df,kind='line',height=5,aspect=4)
sns.set(font_scale=2)
plt.legend()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_14864\347898968.py:3: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sns.set(font_scale=2)
sns.relplot(x='sepal.length',y='petal.length',hue='variety',data=df)

# %%
sns.set(font_scale=1)
sns.catplot(x='variety',y='sepal.length',data=df)

# %%
sns.catplot(x='variety',y='sepal.length',data=df,kind='box')

# %%
sns.catplot(x='variety',y='sepal.length',data=df,kind='bar')

# %%
sns.catplot(x='variety',y='sepal.length',data=df,kind='point')

# %%
sns.jointplot(x='variety',y='sepal.length',data=df)

# %%
sns.pairplot(df)

# %%
sns.regplot(x='sepal.width',y='sepal.length',data=df)
# Out:
# <Axes: xlabel='sepal.width', ylabel='sepal.length'>
